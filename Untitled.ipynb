# %% [markdown]
# <a href="https://colab.research.google.com/github/keilerdnietoc-rgb/colab/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 SUMA = 0
 print("SUMA =", SUMA)

 X = 20
 print("X =", X)

 SUMA = SUMA + X
 print("SUMA =", SUMA)

 Y = 40
 print("Y =", Y)

 X = X + Y * 2
 print("X =", X)

 SUMA = SUMA + X / Y
 print("SUMA =", SUMA)
# Out:
# SUMA = 0
# X = 20
# SUMA = 20
# Y = 40
# X = 100
# SUMA = 22.5

# %%
horas = 48
valor_hora = 5000
porcentaje_retencion = 0.125

salario_bruto = horas * valor_hora
retencion = salario_bruto * porcentaje_retencion
salario_neto = salario_bruto - retencion

print("Salario bruto:", salario_bruto)
print("Retención:", retencion)
print("Salario neto:", salario_neto)
# Out:
# Salario bruto: 240000
# Retención: 30000.0
# Salario neto: 210000.0
